# %%
from carte_ai.data import lung_cancer

# %%
data = lung_cancer.read_lung_cancer()

data.head()
# Out:
#    Age  Gender Smoking_History  Tumor_Size_mm Tumor_Location      Stage  \
# 0   68    Male  Current Smoker      81.678677     Lower Lobe  Stage III
# 1   58    Male    Never Smoked      78.448272     Lower Lobe    Stage I
# 2   44    Male   Former Smoker      67.714305     Lower Lobe    Stage I
# 3   72    Male  Current Smoker      70.806008     Lower Lobe  Stage III
# 4   37  Female    Never Smoked      87.272433     Lower Lobe   Stage IV
#
#    Treatment  Survival_Months         Ethnicity Insurance_Type  ...  \
# 0          2               44          Hispanic       Medicare  ...
# 1          1              101         Caucasian        Private  ...
# 2          0               69  African American          Other  ...
# 3          0               95  African American       Medicare  ...
# 4          1              105             Asian       Medicaid  ...
#
#   Alanine_Aminotransferase_Level Aspartate_Aminotransferase_Level  \
# ...

# %% [markdown]
# All numerical values are almost perfectly uniformly distributed

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

numerical_cols = data.select_dtypes(include=['number'])
for col in numerical_cols.columns:
    plt.figure(figsize=(8, 4))
    sns.histplot(data=data, x=col, kde=True, bins=30, color='blue')
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.grid(axis='y')
    plt.show()

# %% [markdown]
# More surprising, is that there seems to be absolute no correlation between any of the columns. Even things you'd suspect to be correlated like 'Age' and 'Survival_Months'.
#
# My hunch is that this dataset is synthetic + made of completely independently random values, and that there are no patterns to learn from it.

# %%
numerical_cols = data.select_dtypes(include=['number'])
correlation_matrix = numerical_cols.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, annot_kws={"size": 8}, cmap='coolwarm', fmt=".2f", cbar=True)
plt.title("Pairwise Correlation Heatmap")
plt.show()
